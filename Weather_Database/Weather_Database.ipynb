# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
cities
# Out:
# ['port hedland',
#  'punta arenas',
#  'tsihombe',
#  'bilibino',
#  'vila velha',
#  'salinopolis',
#  'jvari',
#  'yerbogachen',
#  'saint peter',
#  'nanortalik',
#  'ngukurr',
#  'sao filipe',
#  'illoqqortoormiut',
#  'tilichiki',
#  'tiksi',
#  'torbay',
#  'barrow',
#  'rikitea',
#  'hithadhoo',
#  'bambanglipuro',
#  'avarua',
#  'khatanga',
#  'ribeira grande',
#  'bathsheba',
#  'ahipara',
#  'tiznit',
#  'hadgaon',
#  'kanda',
#  'griffith',
#  'radis',
#  'atuona',
#  'hermanus',
#  'taolanaro',
#  'jamestown',
#  'yumen',
#  'uralets',
#  'linchuan',
#  'yellowknife',
#  'dikson',
#  'arraial do cabo',
#  'busselton',
#  'ushuaia',
#  'vila franca do campo',
#  'cape town',
#  'pisco',
#  'tateyama',
#  'nuuk',
#  'bluff',
#  'hunza',
#  'isangel',
#  'verkh-usugli',
#  'baoqing',
#  'oktyabrskiy',
#  'port elizabeth',
#  'bangarapet',
#  'albany',
#  'vaini',
#  'butaritari',
#  'kapaa',
#  'longyearbyen',
#  'providencia',
#  'kokopo',
#  'pochutla',
#  'vaasa',
#  'chagda',
#  'virginia beach',
#  'sao joao da barra',
#  'port alfred',
#  'saleaula',
#  'pavda',
#  'severo-kurilsk',
#  'kamaishi',
#  'ancud',
#  'bubaque',
#  'lompoc',
#  'shingu',
#  'mys shmidta',
#  'marawi',
#  'hilo',
#  'tazovskiy',
#  'magole',
#  'saldanha',
#  'orhei',
#  'cayenne',
#  'tam ky',
#  'provideniya',
#  'chunhuhub',
#  'muisne',
#  'winnemucca',
#  'krasnyye barrikady',
#  'ambilobe',
#  'itarema',
#  'abapo',
#  'tubruq',
#  'hobart',
#  'new norfolk',
#  'vanimo',
#  'bredasdorp',
#  'karakol',
#  'castro',
#  'auki',
#  'constitucion',
#  'marand',
#  'mahebourg',
#  'kavieng',
#  'tupik',
#  'ponta do sol',
#  'rudbar',
#  'paracatu',
#  'cartagena',
#  'shuya',
#  'adrar',
#  'upernavik',
#  'goedereede',
#  'svetlaya',
#  'quatre cocos',
#  'east london',
#  'bethel',
#  'louisbourg',
#  'bengkulu',
#  'georgetown',
#  'fairbanks',
#  'mezen',
#  'koster',
#  'nador',
#  'qaanaaq',
#  'attawapiskat',
#  'dubbo',
#  'mizdah',
#  'kloulklubed',
#  'nikolskoye',
#  'micheweni',
#  'puerto escondido',
#  'mar del plata',
#  'sabang',
#  'rio grande',
#  'chokurdakh',
#  'palabuhanratu',
#  'ust-kamchatsk',
#  'galiwinku',
#  'klaksvik',
#  'santa fe',
#  'lebu',
#  'shakhtinsk',
#  'gua musang',
#  'alofi',
#  'egvekinot',
#  'belushya guba',
#  'waipawa',
#  'carnarvon',
#  'jijiga',
#  'hami',
#  'tabuk',
#  'sioux lookout',
#  'mackay',
#  'sentyabrskiy',
#  'mount pleasant',
#  'karaul',
#  'pedasi',
#  'taltal',
#  'roros',
#  'vieux-habitants',
#  'gat',
#  'zhangjiakou',
#  'toliary',
#  'broken hill',
#  'varadero',
#  'taoudenni',
#  'bacuit',
#  'flinders',
#  'half moon bay',
#  'kruisfontein',
#  'nelson bay',
#  'olafsvik',
#  'mataura',
#  'walvis bay',
#  'quchan',
#  'port blair',
#  'prince rupert',
#  'pangnirtung',
#  'berlevag',
#  'leningradskiy',
#  'galich',
#  'kununurra',
#  'lata',
#  'sal rei',
#  'la ronge',
#  'nome',
#  'saint-augustin',
#  'oksfjord',
#  'kodiak',
#  'awjilah',
#  'skibbereen',
#  'mayo',
#  'sawtell',
#  'zwedru',
#  'ostrovnoy',
#  'sosnovo-ozerskoye',
#  'touros',
#  'copiapo',
#  'souillac',
#  'saskylakh',
#  'nyurba',
#  'cabedelo',
#  'savinka',
#  'miri',
#  'banda aceh',
#  'elizabeth city',
#  'camacha',
#  'campo verde',
#  'dingle',
#  'gizo',
#  'ugoofaaru',
#  'thinadhoo',
#  'almonte',
#  'barentsburg',
#  'bargal',
#  'wausau',
#  'kahului',
#  'bowen',
#  'pachperwa',
#  'hualmay',
#  'rawson',
#  'nampula',
#  'norman wells',
#  'tura',
#  'port lincoln',
#  'utiroa',
#  'kargasok',
#  'vaitupu',
#  'kavaratti',
#  'smithers',
#  'atambua',
#  'piranshahr',
#  'matagami',
#  'faanui',
#  'anadyr',
#  'chuy',
#  'fare',
#  'noumea',
#  'aripuana',
#  'kulhudhuffushi',
#  'yarmouth',
#  'sofiysk',
#  'ha giang',
#  'finschhafen',
#  'hofn',
#  'mallama',
#  'mana',
#  'guerrero negro',
#  'les cayes',
#  'techiman',
#  'gewane',
#  'hokitika',
#  'mae hong son',
#  'victoria',
#  'suntar',
#  'koutiala',
#  'tasiilaq',
#  'kaitangata',
#  'dubai',
#  'cabo rojo',
#  'belaya gora',
#  'zhigansk',
#  'husavik',
#  'aboso',
#  'alice springs',
#  'bani walid',
#  'gonen',
#  'verkhnevilyuysk',
#  'la sarre',
#  'albino',
#  'sorland',
#  'puerto ayora',
#  'petropavlovsk-kamchatskiy',
#  'sitka',
#  'the valley',
#  'airai',
#  'hammerfest',
#  'barawe',
#  'brae',
#  'barcelos',
#  'mandalgovi',
#  'hasaki',
#  'troitskoye',
#  'monrovia',
#  'oeiras',
#  'kawana waters',
#  'we',
#  'san patricio',
#  'saint-pierre',
#  'cabo san lucas',
#  'itupiranga',
#  'gbadolite',
#  'perbaungan',
#  'charters towers',
#  'paita',
#  'buta',
#  'thompson',
#  'volksrust',
#  'saint-philippe',
#  'westport',
#  'inuvik',
#  'salalah',
#  'qaqortoq',
#  'adunatii-copaceni',
#  'aksehir',
#  'kushiro',
#  'hervey bay',
#  'cockburn town',
#  'nizhneyansk',
#  'sahrak',
#  'samusu',
#  'ucluelet',
#  'ayr',
#  'cazaje',
#  'temaraia',
#  'hohhot',
#  'port hardy',
#  'da lat',
#  'mogadishu',
#  'buraydah',
#  'laguna',
#  'esperance',
#  'vilhena',
#  'banjar',
#  'kualakapuas',
#  'nyimba',
#  'hihifo',
#  'kamenskoye',
#  'roseburg',
#  'lima',
#  'sechura',
#  'ormond beach',
#  'tevaitoa',
#  'amderma',
#  'ilulissat',
#  'uray',
#  'ouango',
#  'katherine',
#  'pevek',
#  'waingapu',
#  'manadhoo',
#  'emerald',
#  'padang',
#  'makakilo city',
#  'maghama',
#  'khuzdar',
#  'srednekolymsk',
#  'ordzhonikidze',
#  'forbes',
#  'louis trichardt',
#  'aksarka',
#  'arhus',
#  'bambous virieux',
#  'galesong',
#  'timmins',
#  'opunake',
#  'cairns',
#  'linhares',
#  'manyana',
#  'vestmanna',
#  'thunder bay',
#  'aflu',
#  'talnakh',
#  'olinda',
#  'concepcion del oro',
#  'andevoranto',
#  'neryungri',
#  'ewa beach',
#  'northam',
#  'harbin',
#  'kumluca',
#  'deputatskiy',
#  'sergeyevka',
#  'juigalpa',
#  'vorontsovka',
#  'mount gambier',
#  'paamiut',
#  'derzhavinsk',
#  'acajutla',
#  'san luis',
#  'kapit',
#  'grand river south east',
#  'bayir',
#  'cervo',
#  'ibra',
#  'batagay-alyta',
#  'ust-koksa',
#  'sitia',
#  'yaan',
#  'ati',
#  'wageningen',
#  'bara',
#  'upington',
#  'bontang',
#  'peniche',
#  'sulangan',
#  'orshanka',
#  'koungou',
#  'chimbarongo',
#  'jumla',
#  'luanda',
#  'vestmannaeyjar',
#  'hay river',
#  'liverpool',
#  'hamilton',
#  'nidadavole',
#  'jerantut',
#  'port-gentil',
#  'andarab',
#  'mangrol',
#  'likasi',
#  'barguzin',
#  'churachandpur',
#  'cidreira',
#  'santa maria del rio',
#  'ayan',
#  'baruun-urt',
#  'zachagansk',
#  'praia da vitoria',
#  'tawkar',
#  'west bay',
#  'clifton springs',
#  'kerki',
#  'yevlax',
#  'lashio',
#  'cherskiy',
#  'fort saint john',
#  'sisimiut',
#  'dangriga',
#  'susehri',
#  'north platte',
#  'ozernovskiy',
#  'tuktoyaktuk',
#  'naryan-mar',
#  'saint-gilles',
#  'korla',
#  'banepa',
#  'darhan',
#  'russell',
#  'kodinsk',
#  'moranbah',
#  'mayor pablo lagerenza',
#  'sovetskiy',
#  'birjand',
#  'dalbandin',
#  'visnes',
#  'moyale',
#  'broome',
#  'oshnaviyeh',
#  'bilma',
#  'saint-leu',
#  'ixtapa',
#  'morwell',
#  'katobu',
#  'santa cruz',
#  'doha',
#  'zolotinka',
#  'kirakira',
#  'yantal',
#  'elizabethtown',
#  'tunduru',
#  'oussouye',
#  'coihaique',
#  'umzimvubu',
#  'taksimo',
#  'dumai',
#  'dzilam gonzalez',
#  'cooma',
#  'sinnamary',
#  'haibowan',
#  'inirida',
#  'ahuimanu',
#  'jaru',
#  'aginskoye',
#  'illapel',
#  'chapada dos guimaraes',
#  'rostaq',
#  'san carlos de bariloche',
#  'mahanje',
#  'vila do maio',
#  'zaozerne',
#  'caravelas',
#  'sept-iles',
#  'itoman',
#  'pingliang',
#  'clyde river',
#  'kazalinsk',
#  'nong chik',
#  'boa vista',
#  'mecca',
#  'bonthe',
#  'jalu',
#  'kobayashi',
#  'dunmore town',
#  'khorramshahr',
#  'bonavista',
#  'saint george',
#  'sorvag',
#  'bocas del toro',
#  'bandarbeyla',
#  'codrington',
#  'seoul',
#  'geraldton',
#  'kalaleh',
#  'altzayanca',
#  'garissa',
#  'sann',
#  'north bend',
#  'uwayl',
#  'dunedin',
#  'road town',
#  'ruatoria',
#  'eldikan',
#  'maceio',
#  'khudumelapye',
#  'pahrump',
#  'peterhead',
#  'atar',
#  'mantua',
#  'urdzhar',
#  'honningsvag',
#  'sao gabriel da cachoeira',
#  'porto novo',
#  'coahuayana',
#  'rungata',
#  'kamakhyanagar',
#  'fallon',
#  'nizwa',
#  'whitehorse',
#  'grand gaube',
#  'jinka',
#  'necochea',
#  'tiruvottiyur',
#  'tautira',
#  'bogotol',
#  'narsaq',
#  'chapais',
#  'madang',
#  'naron',
#  'dhidhdhoo',
#  'santa cruz de la palma',
#  'wadi musa',
#  'gimli',
#  'urengoy',
#  'kolyshley',
#  'ancona',
#  'henties bay',
#  'katangli',
#  'beringovskiy',
#  'vardo',
#  'ust-ilimsk',
#  'canavieiras',
#  'azare',
#  'marsabit',
#  'pasighat',
#  'vila',
#  'muroto',
#  'mahibadhoo',
#  'liaocheng',
#  'numan',
#  'vao',
#  'umm lajj',
#  'pauini',
#  'sola',
#  'paciran',
#  'namatanai',
#  'poum',
#  'turukhansk',
#  'rosoman',
#  'chernyshevskiy',
#  'ayagoz',
#  'alba',
#  'dillon',
#  'fortuna',
#  'tual',
#  'ban nahin',
#  'chingirlau',
#  'teya',
#  'marrakesh',
#  'ipanguacu',
#  'balabac',
#  'palmer',
#  'blagodarnyy',
#  'salem',
#  'kingston',
#  'ordubad',
#  'tigil',
#  'cacule',
#  'bereda',
#  'luderitz',
#  'lazaro cardenas',
#  'upata',
#  'moron',
#  'atasu',
#  'awbari',
#  'castanos',
#  'okha',
#  'zapresic',
#  'erenhot',
#  'antofagasta',
#  'pavelets',
#  'alenquer',
#  'panguna',
#  'maiduguri',
#  'storforshei',
#  'ilembo',
#  'portland',
#  'qarayeri',
#  'karkaralinsk',
#  'tema',
#  'hovd',
#  'buala',
#  'mildura',
#  'okhotsk',
#  'pedernales',
#  'san roque',
#  'la rioja',
#  'lolua',
#  'gwadar',
#  'la fria',
#  'ellisras',
#  'baykit',
#  'bucerias',
#  'cordoba',
#  'gombong',
#  'puerto carreno',
#  'severobaykalsk',
#  'coria',
#  'kommunar',
#  'doka',
#  'buin',
#  'falam',
#  'houma',
#  'namibe',
#  'oranjemund',
#  'stamata',
#  'vidosi',
#  'keti bandar',
#  'kabanjahe',
#  'gushikawa',
#  'boquira',
#  'anchorage',
#  'terekli-mekteb',
#  'hirara',
#  'davidson',
#  'sumbe',
#  'lukovetskiy',
#  'zhuanghe',
#  'senno',
#  'omsukchan',
#  'inderborskiy',
#  'semnan',
#  'lao cai',
#  'oistins',
#  'opportunity',
#  'camopi',
#  'viligili',
#  'craig',
#  'bogorodskoye',
#  'storsteinnes',
#  'labytnangi',
#  'samarai',
#  'mykolayivka',
#  'tuatapere',
#  'lagoa',
#  'bongaree',
#  'huarmey',
#  'mineros',
#  'yulara',
#  'aksu',
#  'havre-saint-pierre',
#  'tsaratanana',
#  'manoel urbano',
#  'alampur',
#  'xining',
#  'dakar',
#  'kidal',
#  'college',
#  'puebloviejo',
#  'maragogi',
#  'waiouru',
#  'siderno',
#  'fevralsk',
#  'comodoro rivadavia',
#  'general roca',
#  'gao',
#  'yatou',
#  'senneterre',
#  'kosikha',
#  'marzuq',
#  'millinocket',
#  'rocha',
#  'nago',
#  'sonqor',
#  'harper',
#  'honiara',
#  'kargil',
#  'verkhoshizhemye',
#  'richards bay',
#  'revelstoke',
#  'gari',
#  'canico',
#  'kangaatsiaq',
#  'kyela',
#  'nantucket',
#  'maningrida',
#  'san quintin',
#  'rundu',
#  'zeya',
#  'whyalla',
#  'juneau',
#  'west plains',
#  'ye',
#  'saqqez',
#  'burlatskoye',
#  'poya',
#  'katsuura',
#  'hsinchu',
#  'berdigestyakh',
#  'shancheng',
#  'atherton',
#  'talcahuano',
#  'dembi dolo',
#  'ibirama',
#  'goderich',
#  'te anau',
#  'ludvika',
#  'zaysan',
#  'khonsa',
#  'warqla',
#  'key biscayne',
#  'fort dodge',
#  'sotuta',
#  'brownwood',
#  'gubin',
#  'muros',
#  'haines junction',
#  'athabasca',
#  'samokov',
#  'coruripe',
#  'voskresenskoye',
#  'sambava',
#  'komsomolskiy',
#  'celestun',
#  'champerico',
#  'magadan',
#  'bardiyah',
#  'salinas',
#  'puerto rondon',
#  'meulaboh',
#  'manono',
#  'herat',
#  'bystryy istok',
#  'tiarei',
#  'moncao',
#  'bourail',
#  'westpunt',
#  'pacific grove',
#  'helong',
#  'dicabisagan',
#  'moindou',
#  'karratha',
#  'nazret',
#  'limbang',
#  'maridi',
#  'portoferraio',
#  'san cristobal',
#  'mercedes',
#  'ternate',
#  'quechultenango',
#  'strelka',
#  'calama',
#  'razole',
#  'norrtalje',
#  'yauya',
#  'amot',
#  'quang ngai',
#  'marquette']

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
city_url = url + "&q=" + "saint peter"
requests.get(city_url).json()
# Out:
# {'coord': {'lon': -59.6167, 'lat': 13.25},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01n'}],
#  'base': 'stations',
#  'main': {'temp': 72.16,
#   'feels_like': 72.46,
#   'temp_min': 72.16,
#   'temp_max': 72.16,
#   'pressure': 1015,
#   'humidity': 72,
#   'sea_level': 1015,
#   'grnd_level': 996},
#  'visibility': 10000,
#  'wind': {'speed': 12.41, 'deg': 54, 'gust': 14.09},
#  'clouds': {'all': 1},
#  'dt': 1675225220,
#  'sys': {'type': 1,
#   'id': 8772,
#   'country': 'BB',
#   'sunrise': 1675247102,
#   'sunset': 1675288733},
#  'timezone': -14400,
#  'id': 3373554,
#  'name': 'Saint Peter',
#  'cod': 200}

# %%
city_weather["weather"][0]["description"]
# Out:
# 'overcast clouds'

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_desc = city_weather["weather"][0]["description"]
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_desc})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port hedland
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 4 of Set 1 | bilibino
# Processing Record 5 of Set 1 | vila velha
# Processing Record 6 of Set 1 | salinopolis
# Processing Record 7 of Set 1 | jvari
# Processing Record 8 of Set 1 | yerbogachen
# Processing Record 9 of Set 1 | saint peter
# Processing Record 10 of Set 1 | nanortalik
# Processing Record 11 of Set 1 | ngukurr
# City not found. Skipping...
# Processing Record 12 of Set 1 | sao filipe
# Processing Record 13 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 14 of Set 1 | tilichiki
# Processing Record 15 of Set 1 | tiksi
# Processing Record 16 of Set 1 | torbay
# Processing Record 17 of Set 1 | barrow
# Processing Record 18 of Set 1 | rikitea
# Processing Record 19 of Set 1 | hithadhoo
# Processing Record 20 of Set 1 | bambanglipuro
# Processing Record 21 of Set 1 | avarua
# Processing Record 22 of Set 1 | khatanga
# Processing Record 23 of Set 1 | ribeira grande
# Processing Record 24 of Set 1 | bathsheba
# Processing Record 25 of Set 1 | ahipara
# Processing Record 26 of Set 1 | tiznit
# Processing Record 27 of Set 1 | hadgaon
# Processing Record 28 of Set 1 | kanda
# Processing Record 29 of Set 1 | griffith
# Processing Record 30 of Set 1 | radis
# Processing Record 31 of Set 1 | atuona
# Processing Record 32 of Set 1 | hermanus
# Processing Record 33 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 34 of Set 1 | jamestown
# Processing Record 35 of Set 1 | yumen
# Processing Record 36 of Set 1 | uralets
# Processing Record 37 of Set 1 | linchuan
# City not found. Skipping...
# Processing Record 38 of Set 1 | yellowknife
# Processing Record 39 of Set 1 | dikson
# Processing Record 40 of Set 1 | arraial do cabo
# Processing Record 41 of Set 1 | busselton
# Processing Record 42 of Set 1 | ushuaia
# Processing Record 43 of Set 1 | vila franca do campo
# Processing Record 44 of Set 1 | cape town
# Processing Record 45 of Set 1 | pisco
# Processing Record 46 of Set 1 | tateyama
# Processing Record 47 of Set 1 | nuuk
# Processing Record 48 of Set 1 | bluff
# Processing Record 49 of Set 1 | hunza
# City not found. Skipping...
# Processing Record 50 of Set 1 | isangel
# Processing Record 1 of Set 2 | verkh-usugli
# Processing Record 2 of Set 2 | baoqing
# Processing Record 3 of Set 2 | oktyabrskiy
# Processing Record 4 of Set 2 | port elizabeth
# Processing Record 5 of Set 2 | bangarapet
# Processing Record 6 of Set 2 | albany
# Processing Record 7 of Set 2 | vaini
# Processing Record 8 of Set 2 | butaritari
# Processing Record 9 of Set 2 | kapaa
# Processing Record 10 of Set 2 | longyearbyen
# Processing Record 11 of Set 2 | providencia
# Processing Record 12 of Set 2 | kokopo
# Processing Record 13 of Set 2 | pochutla
# Processing Record 14 of Set 2 | vaasa
# Processing Record 15 of Set 2 | chagda
# City not found. Skipping...
# Processing Record 16 of Set 2 | virginia beach
# Processing Record 17 of Set 2 | sao joao da barra
# Processing Record 18 of Set 2 | port alfred
# Processing Record 19 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 20 of Set 2 | pavda
# City not found. Skipping...
# Processing Record 21 of Set 2 | severo-kurilsk
# Processing Record 22 of Set 2 | kamaishi
# Processing Record 23 of Set 2 | ancud
# Processing Record 24 of Set 2 | bubaque
# Processing Record 25 of Set 2 | lompoc
# Processing Record 26 of Set 2 | shingu
# Processing Record 27 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 28 of Set 2 | marawi
# Processing Record 29 of Set 2 | hilo
# Processing Record 30 of Set 2 | tazovskiy
# Processing Record 31 of Set 2 | magole
# Processing Record 32 of Set 2 | saldanha
# Processing Record 33 of Set 2 | orhei
# Processing Record 34 of Set 2 | cayenne
# Processing Record 35 of Set 2 | tam ky
# Processing Record 36 of Set 2 | provideniya
# Processing Record 37 of Set 2 | chunhuhub
# Processing Record 38 of Set 2 | muisne
# Processing Record 39 of Set 2 | winnemucca
# Processing Record 40 of Set 2 | krasnyye barrikady
# Processing Record 41 of Set 2 | ambilobe
# Processing Record 42 of Set 2 | itarema
# Processing Record 43 of Set 2 | abapo
# Processing Record 44 of Set 2 | tubruq
# City not found. Skipping...
# Processing Record 45 of Set 2 | hobart
# Processing Record 46 of Set 2 | new norfolk
# Processing Record 47 of Set 2 | vanimo
# Processing Record 48 of Set 2 | bredasdorp
# Processing Record 49 of Set 2 | karakol
# Processing Record 50 of Set 2 | castro
# Processing Record 1 of Set 3 | auki
# Processing Record 2 of Set 3 | constitucion
# Processing Record 3 of Set 3 | marand
# Processing Record 4 of Set 3 | mahebourg
# Processing Record 5 of Set 3 | kavieng
# Processing Record 6 of Set 3 | tupik
# Processing Record 7 of Set 3 | ponta do sol
# Processing Record 8 of Set 3 | rudbar
# Processing Record 9 of Set 3 | paracatu
# Processing Record 10 of Set 3 | cartagena
# Processing Record 11 of Set 3 | shuya
# Processing Record 12 of Set 3 | adrar
# Processing Record 13 of Set 3 | upernavik
# Processing Record 14 of Set 3 | goedereede
# Processing Record 15 of Set 3 | svetlaya
# Processing Record 16 of Set 3 | quatre cocos
# Processing Record 17 of Set 3 | east london
# Processing Record 18 of Set 3 | bethel
# Processing Record 19 of Set 3 | louisbourg
# City not found. Skipping...
# Processing Record 20 of Set 3 | bengkulu
# Processing Record 21 of Set 3 | georgetown
# Processing Record 22 of Set 3 | fairbanks
# Processing Record 23 of Set 3 | mezen
# Processing Record 24 of Set 3 | koster
# Processing Record 25 of Set 3 | nador
# Processing Record 26 of Set 3 | qaanaaq
# Processing Record 27 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 28 of Set 3 | dubbo
# Processing Record 29 of Set 3 | mizdah
# Processing Record 30 of Set 3 | kloulklubed
# Processing Record 31 of Set 3 | nikolskoye
# Processing Record 32 of Set 3 | micheweni
# Processing Record 33 of Set 3 | puerto escondido
# Processing Record 34 of Set 3 | mar del plata
# Processing Record 35 of Set 3 | sabang
# Processing Record 36 of Set 3 | rio grande
# Processing Record 37 of Set 3 | chokurdakh
# Processing Record 38 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 39 of Set 3 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 40 of Set 3 | galiwinku
# City not found. Skipping...
# Processing Record 41 of Set 3 | klaksvik
# Processing Record 42 of Set 3 | santa fe
# Processing Record 43 of Set 3 | lebu
# Processing Record 44 of Set 3 | shakhtinsk
# Processing Record 45 of Set 3 | gua musang
# Processing Record 46 of Set 3 | alofi
# Processing Record 47 of Set 3 | egvekinot
# Processing Record 48 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 49 of Set 3 | waipawa
# Processing Record 50 of Set 3 | carnarvon
# Processing Record 1 of Set 4 | jijiga
# Processing Record 2 of Set 4 | hami
# Processing Record 3 of Set 4 | tabuk
# Processing Record 4 of Set 4 | sioux lookout
# Processing Record 5 of Set 4 | mackay
# Processing Record 6 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 7 of Set 4 | mount pleasant
# Processing Record 8 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 9 of Set 4 | pedasi
# Processing Record 10 of Set 4 | taltal
# Processing Record 11 of Set 4 | roros
# Processing Record 12 of Set 4 | vieux-habitants
# Processing Record 13 of Set 4 | gat
# Processing Record 14 of Set 4 | zhangjiakou
# Processing Record 15 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 16 of Set 4 | broken hill
# Processing Record 17 of Set 4 | varadero
# Processing Record 18 of Set 4 | taoudenni
# Processing Record 19 of Set 4 | bacuit
# City not found. Skipping...
# Processing Record 20 of Set 4 | flinders
# Processing Record 21 of Set 4 | half moon bay
# Processing Record 22 of Set 4 | kruisfontein
# Processing Record 23 of Set 4 | nelson bay
# Processing Record 24 of Set 4 | olafsvik
# Processing Record 25 of Set 4 | mataura
# Processing Record 26 of Set 4 | walvis bay
# Processing Record 27 of Set 4 | quchan
# Processing Record 28 of Set 4 | port blair
# Processing Record 29 of Set 4 | prince rupert
# Processing Record 30 of Set 4 | pangnirtung
# Processing Record 31 of Set 4 | berlevag
# Processing Record 32 of Set 4 | leningradskiy
# Processing Record 33 of Set 4 | galich
# Processing Record 34 of Set 4 | kununurra
# Processing Record 35 of Set 4 | lata
# Processing Record 36 of Set 4 | sal rei
# Processing Record 37 of Set 4 | la ronge
# Processing Record 38 of Set 4 | nome
# Processing Record 39 of Set 4 | saint-augustin
# Processing Record 40 of Set 4 | oksfjord
# Processing Record 41 of Set 4 | kodiak
# Processing Record 42 of Set 4 | awjilah
# Processing Record 43 of Set 4 | skibbereen
# Processing Record 44 of Set 4 | mayo
# Processing Record 45 of Set 4 | sawtell
# Processing Record 46 of Set 4 | zwedru
# Processing Record 47 of Set 4 | ostrovnoy
# Processing Record 48 of Set 4 | sosnovo-ozerskoye
# Processing Record 49 of Set 4 | touros
# Processing Record 50 of Set 4 | copiapo
# Processing Record 1 of Set 5 | souillac
# Processing Record 2 of Set 5 | saskylakh
# Processing Record 3 of Set 5 | nyurba
# Processing Record 4 of Set 5 | cabedelo
# Processing Record 5 of Set 5 | savinka
# Processing Record 6 of Set 5 | miri
# Processing Record 7 of Set 5 | banda aceh
# Processing Record 8 of Set 5 | elizabeth city
# Processing Record 9 of Set 5 | camacha
# Processing Record 10 of Set 5 | campo verde
# Processing Record 11 of Set 5 | dingle
# Processing Record 12 of Set 5 | gizo
# Processing Record 13 of Set 5 | ugoofaaru
# Processing Record 14 of Set 5 | thinadhoo
# Processing Record 15 of Set 5 | almonte
# Processing Record 16 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 17 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 18 of Set 5 | wausau
# Processing Record 19 of Set 5 | kahului
# Processing Record 20 of Set 5 | bowen
# Processing Record 21 of Set 5 | pachperwa
# Processing Record 22 of Set 5 | hualmay
# Processing Record 23 of Set 5 | rawson
# Processing Record 24 of Set 5 | nampula
# Processing Record 25 of Set 5 | norman wells
# Processing Record 26 of Set 5 | tura
# Processing Record 27 of Set 5 | port lincoln
# Processing Record 28 of Set 5 | utiroa
# City not found. Skipping...
# Processing Record 29 of Set 5 | kargasok
# Processing Record 30 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 31 of Set 5 | kavaratti
# Processing Record 32 of Set 5 | smithers
# Processing Record 33 of Set 5 | atambua
# Processing Record 34 of Set 5 | piranshahr
# Processing Record 35 of Set 5 | matagami
# Processing Record 36 of Set 5 | faanui
# Processing Record 37 of Set 5 | anadyr
# Processing Record 38 of Set 5 | chuy
# Processing Record 39 of Set 5 | fare
# Processing Record 40 of Set 5 | noumea
# Processing Record 41 of Set 5 | aripuana
# Processing Record 42 of Set 5 | kulhudhuffushi
# Processing Record 43 of Set 5 | yarmouth
# Processing Record 44 of Set 5 | sofiysk
# City not found. Skipping...
# Processing Record 45 of Set 5 | ha giang
# Processing Record 46 of Set 5 | finschhafen
# Processing Record 47 of Set 5 | hofn
# Processing Record 48 of Set 5 | mallama
# City not found. Skipping...
# Processing Record 49 of Set 5 | mana
# Processing Record 50 of Set 5 | guerrero negro
# Processing Record 1 of Set 6 | les cayes
# Processing Record 2 of Set 6 | techiman
# Processing Record 3 of Set 6 | gewane
# Processing Record 4 of Set 6 | hokitika
# Processing Record 5 of Set 6 | mae hong son
# Processing Record 6 of Set 6 | victoria
# Processing Record 7 of Set 6 | suntar
# Processing Record 8 of Set 6 | koutiala
# Processing Record 9 of Set 6 | tasiilaq
# Processing Record 10 of Set 6 | kaitangata
# Processing Record 11 of Set 6 | dubai
# Processing Record 12 of Set 6 | cabo rojo
# Processing Record 13 of Set 6 | belaya gora
# Processing Record 14 of Set 6 | zhigansk
# Processing Record 15 of Set 6 | husavik
# Processing Record 16 of Set 6 | aboso
# Processing Record 17 of Set 6 | alice springs
# Processing Record 18 of Set 6 | bani walid
# Processing Record 19 of Set 6 | gonen
# Processing Record 20 of Set 6 | verkhnevilyuysk
# Processing Record 21 of Set 6 | la sarre
# Processing Record 22 of Set 6 | albino
# Processing Record 23 of Set 6 | sorland
# Processing Record 24 of Set 6 | puerto ayora
# Processing Record 25 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 26 of Set 6 | sitka
# Processing Record 27 of Set 6 | the valley
# Processing Record 28 of Set 6 | airai
# Processing Record 29 of Set 6 | hammerfest
# Processing Record 30 of Set 6 | barawe
# City not found. Skipping...
# Processing Record 31 of Set 6 | brae
# Processing Record 32 of Set 6 | barcelos
# Processing Record 33 of Set 6 | mandalgovi
# Processing Record 34 of Set 6 | hasaki
# Processing Record 35 of Set 6 | troitskoye
# Processing Record 36 of Set 6 | monrovia
# Processing Record 37 of Set 6 | oeiras
# Processing Record 38 of Set 6 | kawana waters
# City not found. Skipping...
# Processing Record 39 of Set 6 | we
# City not found. Skipping...
# Processing Record 40 of Set 6 | san patricio
# Processing Record 41 of Set 6 | saint-pierre
# Processing Record 42 of Set 6 | cabo san lucas
# Processing Record 43 of Set 6 | itupiranga
# Processing Record 44 of Set 6 | gbadolite
# Processing Record 45 of Set 6 | perbaungan
# Processing Record 46 of Set 6 | charters towers
# Processing Record 47 of Set 6 | paita
# Processing Record 48 of Set 6 | buta
# Processing Record 49 of Set 6 | thompson
# Processing Record 50 of Set 6 | volksrust
# Processing Record 1 of Set 7 | saint-philippe
# Processing Record 2 of Set 7 | westport
# Processing Record 3 of Set 7 | inuvik
# Processing Record 4 of Set 7 | salalah
# Processing Record 5 of Set 7 | qaqortoq
# Processing Record 6 of Set 7 | adunatii-copaceni
# City not found. Skipping...
# Processing Record 7 of Set 7 | aksehir
# Processing Record 8 of Set 7 | kushiro
# Processing Record 9 of Set 7 | hervey bay
# Processing Record 10 of Set 7 | cockburn town
# Processing Record 11 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 12 of Set 7 | sahrak
# City not found. Skipping...
# Processing Record 13 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 14 of Set 7 | ucluelet
# Processing Record 15 of Set 7 | ayr
# Processing Record 16 of Set 7 | cazaje
# City not found. Skipping...
# Processing Record 17 of Set 7 | temaraia
# City not found. Skipping...
# Processing Record 18 of Set 7 | hohhot
# Processing Record 19 of Set 7 | port hardy
# Processing Record 20 of Set 7 | da lat
# Processing Record 21 of Set 7 | mogadishu
# Processing Record 22 of Set 7 | buraydah
# Processing Record 23 of Set 7 | laguna
# Processing Record 24 of Set 7 | esperance
# Processing Record 25 of Set 7 | vilhena
# Processing Record 26 of Set 7 | banjar
# Processing Record 27 of Set 7 | kualakapuas
# Processing Record 28 of Set 7 | nyimba
# Processing Record 29 of Set 7 | hihifo
# City not found. Skipping...
# Processing Record 30 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 31 of Set 7 | roseburg
# Processing Record 32 of Set 7 | lima
# Processing Record 33 of Set 7 | sechura
# Processing Record 34 of Set 7 | ormond beach
# Processing Record 35 of Set 7 | tevaitoa
# Processing Record 36 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 37 of Set 7 | ilulissat
# Processing Record 38 of Set 7 | uray
# Processing Record 39 of Set 7 | ouango
# Processing Record 40 of Set 7 | katherine
# Processing Record 41 of Set 7 | pevek
# Processing Record 42 of Set 7 | waingapu
# Processing Record 43 of Set 7 | manadhoo
# Processing Record 44 of Set 7 | emerald
# Processing Record 45 of Set 7 | padang
# Processing Record 46 of Set 7 | makakilo city
# Processing Record 47 of Set 7 | maghama
# City not found. Skipping...
# Processing Record 48 of Set 7 | khuzdar
# Processing Record 49 of Set 7 | srednekolymsk
# Processing Record 50 of Set 7 | ordzhonikidze
# Processing Record 1 of Set 8 | forbes
# Processing Record 2 of Set 8 | louis trichardt
# Processing Record 3 of Set 8 | aksarka
# Processing Record 4 of Set 8 | arhus
# Processing Record 5 of Set 8 | bambous virieux
# Processing Record 6 of Set 8 | galesong
# Processing Record 7 of Set 8 | timmins
# Processing Record 8 of Set 8 | opunake
# Processing Record 9 of Set 8 | cairns
# Processing Record 10 of Set 8 | linhares
# Processing Record 11 of Set 8 | manyana
# Processing Record 12 of Set 8 | vestmanna
# Processing Record 13 of Set 8 | thunder bay
# Processing Record 14 of Set 8 | aflu
# City not found. Skipping...
# Processing Record 15 of Set 8 | talnakh
# Processing Record 16 of Set 8 | olinda
# Processing Record 17 of Set 8 | concepcion del oro
# Processing Record 18 of Set 8 | andevoranto
# City not found. Skipping...
# Processing Record 19 of Set 8 | neryungri
# Processing Record 20 of Set 8 | ewa beach
# Processing Record 21 of Set 8 | northam
# Processing Record 22 of Set 8 | harbin
# Processing Record 23 of Set 8 | kumluca
# Processing Record 24 of Set 8 | deputatskiy
# Processing Record 25 of Set 8 | sergeyevka
# Processing Record 26 of Set 8 | juigalpa
# Processing Record 27 of Set 8 | vorontsovka
# Processing Record 28 of Set 8 | mount gambier
# Processing Record 29 of Set 8 | paamiut
# Processing Record 30 of Set 8 | derzhavinsk
# Processing Record 31 of Set 8 | acajutla
# Processing Record 32 of Set 8 | san luis
# Processing Record 33 of Set 8 | kapit
# Processing Record 34 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 35 of Set 8 | bayir
# Processing Record 36 of Set 8 | cervo
# Processing Record 37 of Set 8 | ibra
# Processing Record 38 of Set 8 | batagay-alyta
# Processing Record 39 of Set 8 | ust-koksa
# Processing Record 40 of Set 8 | sitia
# Processing Record 41 of Set 8 | yaan
# Processing Record 42 of Set 8 | ati
# Processing Record 43 of Set 8 | wageningen
# Processing Record 44 of Set 8 | bara
# Processing Record 45 of Set 8 | upington
# Processing Record 46 of Set 8 | bontang
# Processing Record 47 of Set 8 | peniche
# Processing Record 48 of Set 8 | sulangan
# Processing Record 49 of Set 8 | orshanka
# Processing Record 50 of Set 8 | koungou
# Processing Record 1 of Set 9 | chimbarongo
# Processing Record 2 of Set 9 | jumla
# Processing Record 3 of Set 9 | luanda
# Processing Record 4 of Set 9 | vestmannaeyjar
# Processing Record 5 of Set 9 | hay river
# Processing Record 6 of Set 9 | liverpool
# Processing Record 7 of Set 9 | hamilton
# Processing Record 8 of Set 9 | nidadavole
# Processing Record 9 of Set 9 | jerantut
# Processing Record 10 of Set 9 | port-gentil
# Processing Record 11 of Set 9 | andarab
# City not found. Skipping...
# Processing Record 12 of Set 9 | mangrol
# Processing Record 13 of Set 9 | likasi
# Processing Record 14 of Set 9 | barguzin
# Processing Record 15 of Set 9 | churachandpur
# Processing Record 16 of Set 9 | cidreira
# Processing Record 17 of Set 9 | santa maria del rio
# Processing Record 18 of Set 9 | ayan
# Processing Record 19 of Set 9 | baruun-urt
# Processing Record 20 of Set 9 | zachagansk
# City not found. Skipping...
# Processing Record 21 of Set 9 | praia da vitoria
# Processing Record 22 of Set 9 | tawkar
# City not found. Skipping...
# Processing Record 23 of Set 9 | west bay
# Processing Record 24 of Set 9 | clifton springs
# Processing Record 25 of Set 9 | kerki
# City not found. Skipping...
# Processing Record 26 of Set 9 | yevlax
# Processing Record 27 of Set 9 | lashio
# Processing Record 28 of Set 9 | cherskiy
# Processing Record 29 of Set 9 | fort saint john
# City not found. Skipping...
# Processing Record 30 of Set 9 | sisimiut
# Processing Record 31 of Set 9 | dangriga
# Processing Record 32 of Set 9 | susehri
# Processing Record 33 of Set 9 | north platte
# Processing Record 34 of Set 9 | ozernovskiy
# Processing Record 35 of Set 9 | tuktoyaktuk
# Processing Record 36 of Set 9 | naryan-mar
# Processing Record 37 of Set 9 | saint-gilles
# Processing Record 38 of Set 9 | korla
# Processing Record 39 of Set 9 | banepa
# Processing Record 40 of Set 9 | darhan
# Processing Record 41 of Set 9 | russell
# Processing Record 42 of Set 9 | kodinsk
# Processing Record 43 of Set 9 | moranbah
# Processing Record 44 of Set 9 | mayor pablo lagerenza
# Processing Record 45 of Set 9 | sovetskiy
# Processing Record 46 of Set 9 | birjand
# Processing Record 47 of Set 9 | dalbandin
# Processing Record 48 of Set 9 | visnes
# Processing Record 49 of Set 9 | moyale
# Processing Record 50 of Set 9 | broome
# Processing Record 1 of Set 10 | oshnaviyeh
# Processing Record 2 of Set 10 | bilma
# Processing Record 3 of Set 10 | saint-leu
# Processing Record 4 of Set 10 | ixtapa
# Processing Record 5 of Set 10 | morwell
# Processing Record 6 of Set 10 | katobu
# Processing Record 7 of Set 10 | santa cruz
# Processing Record 8 of Set 10 | doha
# Processing Record 9 of Set 10 | zolotinka
# City not found. Skipping...
# Processing Record 10 of Set 10 | kirakira
# Processing Record 11 of Set 10 | yantal
# Processing Record 12 of Set 10 | elizabethtown
# Processing Record 13 of Set 10 | tunduru
# City not found. Skipping...
# Processing Record 14 of Set 10 | oussouye
# Processing Record 15 of Set 10 | coihaique
# Processing Record 16 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 17 of Set 10 | taksimo
# Processing Record 18 of Set 10 | dumai
# Processing Record 19 of Set 10 | dzilam gonzalez
# Processing Record 20 of Set 10 | cooma
# Processing Record 21 of Set 10 | sinnamary
# Processing Record 22 of Set 10 | haibowan
# City not found. Skipping...
# Processing Record 23 of Set 10 | inirida
# Processing Record 24 of Set 10 | ahuimanu
# Processing Record 25 of Set 10 | jaru
# Processing Record 26 of Set 10 | aginskoye
# Processing Record 27 of Set 10 | illapel
# Processing Record 28 of Set 10 | chapada dos guimaraes
# Processing Record 29 of Set 10 | rostaq
# City not found. Skipping...
# Processing Record 30 of Set 10 | san carlos de bariloche
# Processing Record 31 of Set 10 | mahanje
# Processing Record 32 of Set 10 | vila do maio
# Processing Record 33 of Set 10 | zaozerne
# Processing Record 34 of Set 10 | caravelas
# Processing Record 35 of Set 10 | sept-iles
# Processing Record 36 of Set 10 | itoman
# Processing Record 37 of Set 10 | pingliang
# Processing Record 38 of Set 10 | clyde river
# Processing Record 39 of Set 10 | kazalinsk
# City not found. Skipping...
# Processing Record 40 of Set 10 | nong chik
# Processing Record 41 of Set 10 | boa vista
# Processing Record 42 of Set 10 | mecca
# Processing Record 43 of Set 10 | bonthe
# Processing Record 44 of Set 10 | jalu
# Processing Record 45 of Set 10 | kobayashi
# Processing Record 46 of Set 10 | dunmore town
# Processing Record 47 of Set 10 | khorramshahr
# Processing Record 48 of Set 10 | bonavista
# Processing Record 49 of Set 10 | saint george
# Processing Record 50 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 1 of Set 11 | bocas del toro
# Processing Record 2 of Set 11 | bandarbeyla
# Processing Record 3 of Set 11 | codrington
# Processing Record 4 of Set 11 | seoul
# Processing Record 5 of Set 11 | geraldton
# Processing Record 6 of Set 11 | kalaleh
# Processing Record 7 of Set 11 | altzayanca
# Processing Record 8 of Set 11 | garissa
# Processing Record 9 of Set 11 | sann
# Processing Record 10 of Set 11 | north bend
# Processing Record 11 of Set 11 | uwayl
# City not found. Skipping...
# Processing Record 12 of Set 11 | dunedin
# Processing Record 13 of Set 11 | road town
# Processing Record 14 of Set 11 | ruatoria
# City not found. Skipping...
# Processing Record 15 of Set 11 | eldikan
# City not found. Skipping...
# Processing Record 16 of Set 11 | maceio
# Processing Record 17 of Set 11 | khudumelapye
# Processing Record 18 of Set 11 | pahrump
# Processing Record 19 of Set 11 | peterhead
# Processing Record 20 of Set 11 | atar
# Processing Record 21 of Set 11 | mantua
# Processing Record 22 of Set 11 | urdzhar
# City not found. Skipping...
# Processing Record 23 of Set 11 | honningsvag
# Processing Record 24 of Set 11 | sao gabriel da cachoeira
# Processing Record 25 of Set 11 | porto novo
# Processing Record 26 of Set 11 | coahuayana
# Processing Record 27 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 28 of Set 11 | kamakhyanagar
# Processing Record 29 of Set 11 | fallon
# Processing Record 30 of Set 11 | nizwa
# Processing Record 31 of Set 11 | whitehorse
# Processing Record 32 of Set 11 | grand gaube
# Processing Record 33 of Set 11 | jinka
# Processing Record 34 of Set 11 | necochea
# Processing Record 35 of Set 11 | tiruvottiyur
# City not found. Skipping...
# Processing Record 36 of Set 11 | tautira
# Processing Record 37 of Set 11 | bogotol
# Processing Record 38 of Set 11 | narsaq
# Processing Record 39 of Set 11 | chapais
# Processing Record 40 of Set 11 | madang
# Processing Record 41 of Set 11 | naron
# Processing Record 42 of Set 11 | dhidhdhoo
# Processing Record 43 of Set 11 | santa cruz de la palma
# Processing Record 44 of Set 11 | wadi musa
# Processing Record 45 of Set 11 | gimli
# Processing Record 46 of Set 11 | urengoy
# Processing Record 47 of Set 11 | kolyshley
# Processing Record 48 of Set 11 | ancona
# Processing Record 49 of Set 11 | henties bay
# Processing Record 50 of Set 11 | katangli
# Processing Record 1 of Set 12 | beringovskiy
# Processing Record 2 of Set 12 | vardo
# Processing Record 3 of Set 12 | ust-ilimsk
# Processing Record 4 of Set 12 | canavieiras
# Processing Record 5 of Set 12 | azare
# Processing Record 6 of Set 12 | marsabit
# Processing Record 7 of Set 12 | pasighat
# Processing Record 8 of Set 12 | vila
# Processing Record 9 of Set 12 | muroto
# Processing Record 10 of Set 12 | mahibadhoo
# Processing Record 11 of Set 12 | liaocheng
# Processing Record 12 of Set 12 | numan
# Processing Record 13 of Set 12 | vao
# Processing Record 14 of Set 12 | umm lajj
# Processing Record 15 of Set 12 | pauini
# Processing Record 16 of Set 12 | sola
# Processing Record 17 of Set 12 | paciran
# Processing Record 18 of Set 12 | namatanai
# Processing Record 19 of Set 12 | poum
# Processing Record 20 of Set 12 | turukhansk
# Processing Record 21 of Set 12 | rosoman
# Processing Record 22 of Set 12 | chernyshevskiy
# Processing Record 23 of Set 12 | ayagoz
# Processing Record 24 of Set 12 | alba
# Processing Record 25 of Set 12 | dillon
# Processing Record 26 of Set 12 | fortuna
# Processing Record 27 of Set 12 | tual
# Processing Record 28 of Set 12 | ban nahin
# Processing Record 29 of Set 12 | chingirlau
# Processing Record 30 of Set 12 | teya
# Processing Record 31 of Set 12 | marrakesh
# Processing Record 32 of Set 12 | ipanguacu
# Processing Record 33 of Set 12 | balabac
# Processing Record 34 of Set 12 | palmer
# Processing Record 35 of Set 12 | blagodarnyy
# Processing Record 36 of Set 12 | salem
# Processing Record 37 of Set 12 | kingston
# Processing Record 38 of Set 12 | ordubad
# Processing Record 39 of Set 12 | tigil
# Processing Record 40 of Set 12 | cacule
# Processing Record 41 of Set 12 | bereda
# Processing Record 42 of Set 12 | luderitz
# Processing Record 43 of Set 12 | lazaro cardenas
# Processing Record 44 of Set 12 | upata
# Processing Record 45 of Set 12 | moron
# Processing Record 46 of Set 12 | atasu
# Processing Record 47 of Set 12 | awbari
# Processing Record 48 of Set 12 | castanos
# Processing Record 49 of Set 12 | okha
# Processing Record 50 of Set 12 | zapresic
# Processing Record 1 of Set 13 | erenhot
# Processing Record 2 of Set 13 | antofagasta
# Processing Record 3 of Set 13 | pavelets
# Processing Record 4 of Set 13 | alenquer
# Processing Record 5 of Set 13 | panguna
# Processing Record 6 of Set 13 | maiduguri
# Processing Record 7 of Set 13 | storforshei
# Processing Record 8 of Set 13 | ilembo
# Processing Record 9 of Set 13 | portland
# Processing Record 10 of Set 13 | qarayeri
# Processing Record 11 of Set 13 | karkaralinsk
# City not found. Skipping...
# Processing Record 12 of Set 13 | tema
# Processing Record 13 of Set 13 | hovd
# Processing Record 14 of Set 13 | buala
# Processing Record 15 of Set 13 | mildura
# Processing Record 16 of Set 13 | okhotsk
# Processing Record 17 of Set 13 | pedernales
# Processing Record 18 of Set 13 | san roque
# Processing Record 19 of Set 13 | la rioja
# Processing Record 20 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 21 of Set 13 | gwadar
# Processing Record 22 of Set 13 | la fria
# Processing Record 23 of Set 13 | ellisras
# Processing Record 24 of Set 13 | baykit
# Processing Record 25 of Set 13 | bucerias
# Processing Record 26 of Set 13 | cordoba
# Processing Record 27 of Set 13 | gombong
# Processing Record 28 of Set 13 | puerto carreno
# Processing Record 29 of Set 13 | severobaykalsk
# Processing Record 30 of Set 13 | coria
# Processing Record 31 of Set 13 | kommunar
# Processing Record 32 of Set 13 | doka
# Processing Record 33 of Set 13 | buin
# Processing Record 34 of Set 13 | falam
# Processing Record 35 of Set 13 | houma
# Processing Record 36 of Set 13 | namibe
# Processing Record 37 of Set 13 | oranjemund
# Processing Record 38 of Set 13 | stamata
# Processing Record 39 of Set 13 | vidosi
# Processing Record 40 of Set 13 | keti bandar
# Processing Record 41 of Set 13 | kabanjahe
# Processing Record 42 of Set 13 | gushikawa
# Processing Record 43 of Set 13 | boquira
# Processing Record 44 of Set 13 | anchorage
# Processing Record 45 of Set 13 | terekli-mekteb
# Processing Record 46 of Set 13 | hirara
# Processing Record 47 of Set 13 | davidson
# Processing Record 48 of Set 13 | sumbe
# Processing Record 49 of Set 13 | lukovetskiy
# Processing Record 50 of Set 13 | zhuanghe
# Processing Record 1 of Set 14 | senno
# Processing Record 2 of Set 14 | omsukchan
# Processing Record 3 of Set 14 | inderborskiy
# City not found. Skipping...
# Processing Record 4 of Set 14 | semnan
# Processing Record 5 of Set 14 | lao cai
# Processing Record 6 of Set 14 | oistins
# Processing Record 7 of Set 14 | opportunity
# Processing Record 8 of Set 14 | camopi
# Processing Record 9 of Set 14 | viligili
# City not found. Skipping...
# Processing Record 10 of Set 14 | craig
# Processing Record 11 of Set 14 | bogorodskoye
# Processing Record 12 of Set 14 | storsteinnes
# Processing Record 13 of Set 14 | labytnangi
# Processing Record 14 of Set 14 | samarai
# Processing Record 15 of Set 14 | mykolayivka
# Processing Record 16 of Set 14 | tuatapere
# Processing Record 17 of Set 14 | lagoa
# Processing Record 18 of Set 14 | bongaree
# Processing Record 19 of Set 14 | huarmey
# Processing Record 20 of Set 14 | mineros
# Processing Record 21 of Set 14 | yulara
# Processing Record 22 of Set 14 | aksu
# Processing Record 23 of Set 14 | havre-saint-pierre
# Processing Record 24 of Set 14 | tsaratanana
# Processing Record 25 of Set 14 | manoel urbano
# Processing Record 26 of Set 14 | alampur
# Processing Record 27 of Set 14 | xining
# Processing Record 28 of Set 14 | dakar
# Processing Record 29 of Set 14 | kidal
# Processing Record 30 of Set 14 | college
# Processing Record 31 of Set 14 | puebloviejo
# Processing Record 32 of Set 14 | maragogi
# Processing Record 33 of Set 14 | waiouru
# Processing Record 34 of Set 14 | siderno
# Processing Record 35 of Set 14 | fevralsk
# City not found. Skipping...
# Processing Record 36 of Set 14 | comodoro rivadavia
# Processing Record 37 of Set 14 | general roca
# Processing Record 38 of Set 14 | gao
# Processing Record 39 of Set 14 | yatou
# Processing Record 40 of Set 14 | senneterre
# Processing Record 41 of Set 14 | kosikha
# Processing Record 42 of Set 14 | marzuq
# Processing Record 43 of Set 14 | millinocket
# Processing Record 44 of Set 14 | rocha
# Processing Record 45 of Set 14 | nago
# Processing Record 46 of Set 14 | sonqor
# Processing Record 47 of Set 14 | harper
# Processing Record 48 of Set 14 | honiara
# Processing Record 49 of Set 14 | kargil
# Processing Record 50 of Set 14 | verkhoshizhemye
# Processing Record 1 of Set 15 | richards bay
# Processing Record 2 of Set 15 | revelstoke
# Processing Record 3 of Set 15 | gari
# Processing Record 4 of Set 15 | canico
# Processing Record 5 of Set 15 | kangaatsiaq
# Processing Record 6 of Set 15 | kyela
# Processing Record 7 of Set 15 | nantucket
# Processing Record 8 of Set 15 | maningrida
# Processing Record 9 of Set 15 | san quintin
# Processing Record 10 of Set 15 | rundu
# Processing Record 11 of Set 15 | zeya
# Processing Record 12 of Set 15 | whyalla
# Processing Record 13 of Set 15 | juneau
# Processing Record 14 of Set 15 | west plains
# Processing Record 15 of Set 15 | ye
# City not found. Skipping...
# Processing Record 16 of Set 15 | saqqez
# Processing Record 17 of Set 15 | burlatskoye
# Processing Record 18 of Set 15 | poya
# Processing Record 19 of Set 15 | katsuura
# Processing Record 20 of Set 15 | hsinchu
# Processing Record 21 of Set 15 | berdigestyakh
# Processing Record 22 of Set 15 | shancheng
# Processing Record 23 of Set 15 | atherton
# Processing Record 24 of Set 15 | talcahuano
# Processing Record 25 of Set 15 | dembi dolo
# Processing Record 26 of Set 15 | ibirama
# Processing Record 27 of Set 15 | goderich
# Processing Record 28 of Set 15 | te anau
# Processing Record 29 of Set 15 | ludvika
# Processing Record 30 of Set 15 | zaysan
# Processing Record 31 of Set 15 | khonsa
# Processing Record 32 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 33 of Set 15 | key biscayne
# Processing Record 34 of Set 15 | fort dodge
# Processing Record 35 of Set 15 | sotuta
# Processing Record 36 of Set 15 | brownwood
# Processing Record 37 of Set 15 | gubin
# Processing Record 38 of Set 15 | muros
# Processing Record 39 of Set 15 | haines junction
# Processing Record 40 of Set 15 | athabasca
# Processing Record 41 of Set 15 | samokov
# Processing Record 42 of Set 15 | coruripe
# Processing Record 43 of Set 15 | voskresenskoye
# Processing Record 44 of Set 15 | sambava
# Processing Record 45 of Set 15 | komsomolskiy
# Processing Record 46 of Set 15 | celestun
# Processing Record 47 of Set 15 | champerico
# Processing Record 48 of Set 15 | magadan
# Processing Record 49 of Set 15 | bardiyah
# Processing Record 50 of Set 15 | salinas
# Processing Record 1 of Set 16 | puerto rondon
# Processing Record 2 of Set 16 | meulaboh
# Processing Record 3 of Set 16 | manono
# Processing Record 4 of Set 16 | herat
# Processing Record 5 of Set 16 | bystryy istok
# Processing Record 6 of Set 16 | tiarei
# Processing Record 7 of Set 16 | moncao
# Processing Record 8 of Set 16 | bourail
# Processing Record 9 of Set 16 | westpunt
# City not found. Skipping...
# Processing Record 10 of Set 16 | pacific grove
# Processing Record 11 of Set 16 | helong
# Processing Record 12 of Set 16 | dicabisagan
# Processing Record 13 of Set 16 | moindou
# Processing Record 14 of Set 16 | karratha
# Processing Record 15 of Set 16 | nazret
# Processing Record 16 of Set 16 | limbang
# Processing Record 17 of Set 16 | maridi
# Processing Record 18 of Set 16 | portoferraio
# Processing Record 19 of Set 16 | san cristobal
# Processing Record 20 of Set 16 | mercedes
# Processing Record 21 of Set 16 | ternate
# Processing Record 22 of Set 16 | quechultenango
# Processing Record 23 of Set 16 | strelka
# Processing Record 24 of Set 16 | calama
# Processing Record 25 of Set 16 | razole
# Processing Record 26 of Set 16 | norrtalje
# Processing Record 27 of Set 16 | yauya
# Processing Record 28 of Set 16 | amot
# Processing Record 29 of Set 16 | quang ngai
# Processing Record 30 of Set 16 | marquette
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 711

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Port Hedland      AU -20.3167  118.5667     93.25        59          23
# 1  Punta Arenas      CL -53.1500  -70.9167     53.71        66          40
# 2      Bilibino      RU  68.0546  166.4372      3.24        90          97
# 3    Vila Velha      BR -20.3297  -40.2925     75.15        83          20
# 4   Salinopolis      BR  -0.6136  -47.3561     74.50        95         100
# 5         Jvari      GE  42.7169   42.0520     38.21        66          95
# 6   Yerbogachen      RU  61.2767  108.0108    -10.77        97          97
# 7   Saint Peter      BB  13.2500  -59.6167     72.16        72           1
# 8    Nanortalik      GL  60.1432  -45.2371     14.18        82          99
# 9    Sao Filipe      CV  14.8961  -24.4956     70.56        71          87
#
#    Wind Speed Current Description
# 0       11.50          few clouds
# 1       27.63    scattered clouds
# 2        5.84     overcast clouds
# 3        3.44          few clouds
# 4        2.46       moderate rain
# 5        4.74     overcast clouds
# 6        3.74     overcast clouds
# 7       11.30           clear sky
# 8        6.55     overcast clouds
# 9       10.29     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
city_data_df = city_data_df[["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]]


# Recreate the DataFrame by using the new column order
    # ans: not necessary, already in the correct order


# Display sample data
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Port Hedland      AU -20.3167  118.5667     93.25        59          23
# 1  Punta Arenas      CL -53.1500  -70.9167     53.71        66          40
# 2      Bilibino      RU  68.0546  166.4372      3.24        90          97
# 3    Vila Velha      BR -20.3297  -40.2925     75.15        83          20
# 4   Salinopolis      BR  -0.6136  -47.3561     74.50        95         100
# 5         Jvari      GE  42.7169   42.0520     38.21        66          95
# 6   Yerbogachen      RU  61.2767  108.0108    -10.77        97          97
# 7   Saint Peter      BB  13.2500  -59.6167     72.16        72           1
# 8    Nanortalik      GL  60.1432  -45.2371     14.18        82          99
# 9    Sao Filipe      CV  14.8961  -24.4956     70.56        71          87
#
#    Wind Speed Current Description
# 0       11.50          few clouds
# 1       27.63    scattered clouds
# 2        5.84     overcast clouds
# 3        3.44          few clouds
# 4        2.46       moderate rain
# 5        4.74     overcast clouds
# 6        3.74     overcast clouds
# 7       11.30           clear sky
# 8        6.55     overcast clouds
# 9       10.29     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
